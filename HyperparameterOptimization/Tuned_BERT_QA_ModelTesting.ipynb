# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Installing the "Simple Transformer" library
# !pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Downloading simpletransformers-0.63.11-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (4.65.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2022.10.31)
# Collecting transformers>=4.6.0 (from simpletransformers)
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 30.6 MB/s eta 0:00:00
# Collecting datasets (from simpletransformers)
#   Downloading datasets-2.14.1-py3-none-any.whl (492 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.4/492.4 kB 36.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.2.2)
# Collecting seqeval (from simpletransformers)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (2.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from simpletransformers) (1.5.3)
# Collecting tokenizers (from simpletransformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 59.8 MB/s eta 0:00:00
# Collecting wandb>=0.10.32 (from simpletransformers)
#   Downloading wandb-0.15.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 72.5 MB/s eta 0:00:00
# Collecting streamlit (from simpletransformers)
#   Downloading streamlit-1.25.0-py2.py3-none-any.whl (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 95.5 MB/s eta 0:00:00
# Collecting sentencepiece (from simpletransformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers>=4.6.0->simpletransformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.6.0->simpletransformers) (6.0.1)
# Collecting safetensors>=0.3.1 (from transformers>=4.6.0->simpletransformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.2 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (8.1.6)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading sentry_sdk-1.28.1-py2.py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.7/214.7 kB 27.2 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.10.32->simpletransformers)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb>=0.10.32->simpletransformers)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb>=0.10.32->simpletransformers)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb>=0.10.32->simpletransformers) (3.20.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->simpletransformers) (3.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->simpletransformers)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.3 MB/s eta 0:00:00
# Collecting xxhash (from datasets->simpletransformers)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 26.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->simpletransformers)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->simpletransformers) (3.8.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->simpletransformers) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->simpletransformers) (3.2.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit->simpletransformers) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/lib/python3/dist-packages (from streamlit->simpletransformers) (4.6.4)
# Requirement already satisfied: pillow<10,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (9.4.0)
# Collecting pympler<2,>=0.9 (from streamlit->simpletransformers)
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (13.4.2)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (4.7.1)
# Collecting tzlocal<5,>=1.1 (from streamlit->simpletransformers)
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Collecting validators<1,>=0.2 (from streamlit->simpletransformers)
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pydeck<1,>=0.8 (from streamlit->simpletransformers)
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 86.5 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit->simpletransformers) (6.3.1)
# Collecting watchdog>=2.1.5 (from streamlit->simpletransformers)
#   Downloading watchdog-3.0.0-py3-none-manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->simpletransformers) (0.41.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.14.0)
# Collecting pytz-deprecation-shim (from tzlocal<5,>=1.1->streamlit->simpletransformers)
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from validators<1,>=0.2->streamlit->simpletransformers) (4.4.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->simpletransformers) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.2.2)
# Collecting tzdata (from pytz-deprecation-shim->tzlocal<5,>=1.1->streamlit->simpletransformers)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 39.7 MB/s eta 0:00:00
# Building wheels for collected packages: seqeval, validators, pathtools
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=36d30b7d39372df7ce8f44e9df8d4c0832cf2cfb0db32aeba410648eb579d523
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19580 sha256=f5d00993f527f22c2e9a3a28f37b255b257b7b4eac3bb1955334281f3a7e72c4
#   Stored in directory: /root/.cache/pip/wheels/f2/ed/dd/d3a556ad245ef9dc570c6bcd2f22886d17b0b408dd3bbb9ac3
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=012ef86c57811a9a0fe0a2873510c02efce1fc95333faebee30e2ef0f10908e2
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built seqeval validators pathtools
# Installing collected packages: tokenizers, sentencepiece, safetensors, pathtools, xxhash, watchdog, validators, tzdata, smmap, setproctitle, sentry-sdk, pympler, docker-pycreds, dill, pytz-deprecation-shim, pydeck, multiprocess, huggingface-hub, gitdb, tzlocal, transformers, seqeval, GitPython, wandb, streamlit, datasets, simpletransformers
#   Attempting uninstall: tzlocal
#     Found existing installation: tzlocal 5.0.1
#     Uninstalling tzlocal-5.0.1:
#       Successfully uninstalled tzlocal-5.0.1
# Successfully installed GitPython-3.1.32 datasets-2.14.1 dill-0.3.7 docker-pycreds-0.4.0 gitdb-4.0.10 huggingface-hub-0.16.4 multiprocess-0.70.15 pathtools-0.1.2 pydeck-0.8.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 safetensors-0.3.1 sentencepiece-0.1.99 sentry-sdk-1.28.1 seqeval-1.2.2 setproctitle-1.3.2 simpletransformers-0.63.11 smmap-5.0.0 streamlit-1.25.0 tokenizers-0.13.3 transformers-4.31.0 tzdata-2023.3 tzlocal-4.3.1 validators-0.20.0 wandb-0.15.7 watchdog-3.0.0 xxhash-3.2.0

# %%
# Importing the necessary libraries
import logging
import sklearn
import os
import requests
import json

from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# %%
# Getting training and testing datasets

os.mkdir('squad')
url = 'https://rajpurkar.github.io/SQuAD-explorer/dataset/'

for file in ['train-v2.0.json', 'dev-v2.0.json']:
  res = requests.get(f'{url}{file}') #make request
  with open(f'squad/{file}', 'wb') as f:
    for chunk in res.iter_content(chunk_size=4):
      f.write(chunk)

# %%
# Preparing a testing dataset (6425 samples)
with open("squad/dev-v2.0.json", "rb") as f:
  squad_dict = json.load(f)

test = []
for i in range(17,35):
  test = test + squad_dict['data'][i]['paragraphs']

# %%
print(test[0])
# Out:
# {'qas': [{'question': 'What is it called when people in society rebel against laws they think are unfair?', 'id': '57271c235951b619008f860b', 'answers': [{'text': 'Civil disobedience', 'answer_start': 130}, {'text': 'Civil disobedience', 'answer_start': 130}, {'text': 'Civil disobedience', 'answer_start': 130}, {'text': 'Civil disobedience', 'answer_start': 130}, {'text': 'Civil disobedience', 'answer_start': 130}], 'is_impossible': False}, {'question': 'What is an example of major civil disobedience in South Africa?', 'id': '57271c235951b619008f860c', 'answers': [{'text': 'apartheid', 'answer_start': 497}, {'text': 'fight against apartheid', 'answer_start': 483}, {'text': 'the fight against apartheid', 'answer_start': 479}, {'text': 'the fight against apartheid', 'answer_start': 479}, {'text': 'Singing Revolution to bring independence to the Baltic countries', 'answer_start': 554}], 'is_impossible': False}, {'question': 'What was the the movement called that brought Baltic countries independence from the Soviet Union?', 'id': '57271c235951b619008f860d', 'answers': [{'text': 'Singing Revolution', 'answer_start': 554}, {'text': 'Singing Revolution', 'answer_start': 554}, {'text': 'the Singing Revolution', 'answer_start': 550}, {'text': 'Singing Revolution', 'answer_start': 554}, {'text': 'Singing Revolution', 'answer_start': 554}], 'is_impossible': False}, {'question': 'In 2004 the Orange revolution occurred in what country?', 'id': '57271c235951b619008f860e', 'answers': [{'text': 'Ukraine', 'answer_start': 726}, {'text': 'Ukraine', 'answer_start': 726}, {'text': 'Ukraine', 'answer_start': 726}, {'text': 'Ukraine', 'answer_start': 726}, {'text': 'Ukraine', 'answer_start': 726}], 'is_impossible': False}, {'question': 'Where was the location of the 2003 Rose revolution?', 'id': '57271c235951b619008f860f', 'answers': [{'text': 'Georgia', 'answer_start': 684}, {'text': 'Georgia', 'answer_start': 684}, {'text': 'Georgia', 'answer_start': 684}, {'text': 'Georgia', 'answer_start': 684}, {'text': 'Georgia', 'answer_start': 684}], 'is_impossible': False}, {'question': 'Which people brought forward one of the earliest examples of Civil Disobedience?', 'id': '5728d4c03acd2414000dff9f', 'answers': [{'text': 'Egyptians', 'answer_start': 65}, {'text': 'Egyptians', 'answer_start': 65}, {'text': 'Egyptians', 'answer_start': 65}, {'text': 'Egyptians', 'answer_start': 65}, {'text': 'India', 'answer_start': 296}], 'is_impossible': False}, {'question': 'Who was one of the earliest examples of Civil Disobedience against?', 'id': '5728d4c03acd2414000dffa0', 'answers': [{'text': 'the British', 'answer_start': 83}, {'text': 'British', 'answer_start': 87}, {'text': 'Egyptians against the British occupation in the 1919 Revolution.', 'answer_start': 65}, {'text': 'British occupation', 'answer_start': 87}, {'text': 'communist governments', 'answer_start': 437}], 'is_impossible': False}, {'question': 'Why do people chose civil disobedience to protest?', 'id': '5728d4c03acd2414000dffa1', 'answers': [{'text': 'nonviolent resistance', 'answer_start': 261}, {'text': 'unfair laws', 'answer_start': 223}, {'text': 'nonviolent resistance movements', 'answer_start': 261}, {'text': 'rebelled against what they deem to be unfair', 'answer_start': 185}], 'is_impossible': False}, {'question': 'What does civil disobedience protest against?', 'id': '5728d4c03acd2414000dffa2', 'answers': [{'text': 'unfair laws', 'answer_start': 223}, {'text': 'unfair laws', 'answer_start': 223}, {'text': 'unfair laws.', 'answer_start': 223}, {'text': 'unfair laws', 'answer_start': 223}, {'text': 'what they deem to be unfair', 'answer_start': 202}], 'is_impossible': False}, {'question': "What civil rights movement in the US was known for it's disobedience?", 'id': '5728d4c03acd2414000dffa3', 'answers': [{'text': 'American Civil Rights Movement', 'answer_start': 515}, {'text': 'American Civil Rights Movement', 'answer_start': 515}, {'text': 'American Civil Rights Movement', 'answer_start': 5 ...

# %%
# Load the trained model from Google Drive
model = QuestionAnsweringModel(
    "bert","/content/drive/MyDrive/colab/finalone/best_model"
)

# %% [markdown]
# ---

# %% [markdown]
# ---
# 3. **Test the model.**

# %%
# Test the model
result, texts = model.eval_model(test, test_em_score=sklearn.metrics.accuracy_score)
# Out:
# convert squad examples to features: 100%|██████████| 6425/6425 [00:47<00:00, 135.66it/s]
# add example index and unique id: 100%|██████████| 6425/6425 [00:00<00:00, 861081.39it/s]
# Running Evaluation:   0%|          | 0/102 [00:00<?, ?it/s]

# %%
print(result)
# correct-> number of correct predictions
# similar-> number of similar predictions
# incorrect -> number of incorrect predictions
# test_em_score -> correct/(correct + similar + incorrect)
# Out:
# {'correct': 3730, 'similar': 2504, 'incorrect': 191, 'test_em_score': 0.5805447470817121, 'eval_loss': -6.938648897058823}

# %%
print(texts)
# detailed results
# Out:
# {'correct_text': {'57271c235951b619008f860b': 'Civil disobedience', '5728d4c03acd2414000dff9f': 'Egyptians', '5728d4c03acd2414000dffa2': 'unfair laws', '5a66413dc2b11c001a425ec7': '', '5a66413dc2b11c001a425ec8': '', '5a66413dc2b11c001a425ec9': '', '5a66413dc2b11c001a425eca': '', '5a66413dc2b11c001a425ecb': '', '57271f125951b619008f8635': 'Antigone', '57271f125951b619008f8637': 'Creon', '57271f125951b619008f8639': 'giving her brother Polynices a proper burial', '5728d5793acd2414000dffb3': 'Antigone', '5728d5793acd2414000dffb4': 'Sophocles', '5a664314c2b11c001a425eda': '', '5a664314c2b11c001a425edd': '', '5727213c708984140094da35': 'Percy Shelley', '5727213c708984140094da36': 'nonviolent', '5728d63c4b864d1900164f18': 'Percy Shelley', '5728d63c4b864d1900164f1b': 'Gandhi', '5a664447c2b11c001a425eeb': '', '5a664447c2b11c001a425eec': '', '5a664447c2b11c001a425eed': '', '5a664447c2b11c001a425eef': '', '572726c9708984140094da7c': 'ambiguity', '572726c9708984140094da7d': 'utterly debased', '572726c9708984140094da7e': 'Marshall Cohen', '5728d6f02ca10214002da90e': 'become utterly debased', '5728d6f02ca10214002da90f': 'Marshall Cohen', '5a664612c2b11c001a425f09': '', '5a664612c2b11c001a425f0a': '', '5a664612c2b11c001a425f0b': '', '5a664612c2b11c001a425f0c': '', '5a664612c2b11c001a425f0d': '', '572807802ca10214002d9bf8': 'LeGrande', '572807802ca10214002d9bfb': 'semantical', '5728d7c54b864d1900164f4c': 'LeGrande', '5a6647d2c2b11c001a425f1e': '', '5a6647d2c2b11c001a425f1f': '', '5a6647d2c2b11c001a425f20': '', '5a6647d2c2b11c001a425f21': '', '57280f974b864d1900164374': 'Civil disobedience', '5728d9403acd2414000e001b': 'the state and its laws', '5a665002846392001a1e1ab5': '', '5a665002846392001a1e1ab6': '', '5728dafe3acd2414000e005d': 'The individual', '5a665142846392001a1e1abd': '', '5a665142846392001a1e1abe': '', '5a665142846392001a1e1abf': '', '5a665142846392001a1e1ac0': '', '5a665142846392001a1e1ac1': '', '5a665338846392001a1e1ac8': '', '5a665338846392001a1e1ac9': '', '5a665338846392001a1e1acb': '', '572818f54b864d190016446c': 'civil disobedience', '572818f54b864d190016446d': 'covert lawbreaking', '5728dddc2ca10214002da9d3': 'rules that conflict with morality', '5a665549846392001a1e1ad5': '', '5a665549846392001a1e1ad6': '', '5a665549846392001a1e1ad7': '', '5a665549846392001a1e1ad8': '', '5a665549846392001a1e1ad9': '', '5a665747846392001a1e1ae9': '', '5a665747846392001a1e1aea': '', '5a665747846392001a1e1aeb': '', '5a665747846392001a1e1aec': '', '5a665747846392001a1e1aed': '', '5728202c4b864d19001644ec': 'Revolutionary civil disobedience', '5a665870846392001a1e1af4': '', '5a665870846392001a1e1af5': '', '5a665870846392001a1e1af6': '', '5a665870846392001a1e1af7': '', '5a6659d3846392001a1e1b0d': '', '5a6659d3846392001a1e1b0e': '', '5a6659d3846392001a1e1b0f': '', '5a6659d3846392001a1e1b10': '', '5a6659d3846392001a1e1b11': '', '5a665b56846392001a1e1b1d': '', '5a665b56846392001a1e1b1e': '', '5a665b56846392001a1e1b1f': '', '5a665b56846392001a1e1b20': '', '5a665b56846392001a1e1b21': '', '5728284e3acd2414000df5d1': '1978', '5728e5f43acd2414000e0173': 'Threatening government officials', '5a666b43846392001a1e1c0f': '', '5a666b43846392001a1e1c10': '', '5a666b43846392001a1e1c11': '', '5a666b43846392001a1e1c12': '', '5a6681d1f038b7001ab0bf00': '', '5a6681d1f038b7001ab0bf01': '', '5a6681d1f038b7001ab0bf02': '', '5a6681d1f038b7001ab0bf03': '', '5a6681d1f038b7001ab0bf04': '', '5a6683d5f038b7001ab0bf1e': '', '5a6683d5f038b7001ab0bf1f': '', '5a6683d5f038b7001ab0bf20': '', '5a6683d5f038b7001ab0bf21': '', '5a6683d5f038b7001ab0bf22': '', '5a668632f038b7001ab0bf44': '', '5a668632f038b7001ab0bf45': '', '5a668632f038b7001ab0bf46': '', '5a668632f038b7001ab0bf47': '', '5a668632f038b7001ab0bf48': '', '5728ebcb3acd2414000e01da': 'submit to the punishment prescribed by law', '5a66893ff038b7001ab0bf74': '', '5a66893ff038b7001ab0bf75': '', '5a66893ff038b7001ab0bf76': '', '5a66893ff038b7001ab0bf77': '', '5a66893ff038b7001ab0bf78': '', '5728ec6a4b864d19001650aa': 'Camp Mercu ...

# %% [markdown]
# ---

# %% [markdown]
# ---
# 4. **Answer questions with the model.**

# %%
# The list of questions to be answered

questions = [
    {
        "context": "Vin is a Mistborn of great power and skill.",
        "qas": [
            {
                "question": "What is Vin's speciality?",
                "id": "0",
            }
        ]
    },
    {
        "context": "Bidirectional Encoder Representations from Transformers (BERT) is a family of language models introduced in 2018 by researchers at Google.",
        "qas": [
            {
                "question": "When was BERT introduced?",
                "id": "1",
            }
        ]
    },
    {
        "context": "Bidirectional Encoder Representations from Transformers (BERT) is a family of language models introduced in 2018 by researchers at Google.",
        "qas": [
            {
                "question": "What color is sky?",
                "id": "2",
            }
        ]
    },
    {
        "context": "The 2022 FIFA World Cup was a professional association football tournament, the world championship for national football teams organized by FIFA. The 22nd edition of the FIFA World Cup, it took place in Qatar from 20 November to 18 December 2022, after the country was awarded the hosting rights in 2010. It was the first World Cup to be held in the Arab world and Muslim world, and the second held entirely in Asia after the 2002 tournament in South Korea and Japan.[A] This tournament was the last with 32 participating teams, with the number of teams being increased to 48 for the 2026 edition. To avoid the extremes of Qatar's hot climate,[B] the event was held during November and December.[C] It was held over a reduced time frame of 29 days with 64 matches played in eight venues across five cities. Argentine captain Lionel Messi was voted the tournament's best player, winning the Golden Ball.",
        "qas": [
            {
                "question": "Who was voted the tournament's best player?",
                "id": "3",
            }
        ]
    },
    {
        "context": "The 2022 FIFA World Cup was a professional association football tournament, the world championship for national football teams organized by FIFA. The 22nd edition of the FIFA World Cup, it took place in Qatar from 20 November to 18 December 2022, after the country was awarded the hosting rights in 2010. It was the first World Cup to be held in the Arab world and Muslim world, and the second held entirely in Asia after the 2002 tournament in South Korea and Japan. Argentine captain Lionel Messi was voted the tournament's best player, winning the Golden Ball. [A] This tournament was the last with 32 participating teams, with the number of teams being increased to 48 for the 2026 edition. To avoid the extremes of Qatar's hot climate,[B] the event was held during November and December.[C] It was held over a reduced time frame of 29 days with 64 matches played in eight venues across five cities.",
        "qas": [
            {
                "question": "Who was voted the tournament's best player?",
                "id": "4",
            }
        ]
    },
    {
        "context": "Earth is the third planet from the Sun and the only place known in the universe where life has originated and found habitability.",
        "qas": [
            {
                "question": "What is Earth?",
                "id": "5",
            }
        ]
    },
    {
        "context": "Earth is the third planet from the Sun and the only place known in the universe where life has originated and found habitability.",
        "qas": [
            {
                "question": "Where has life originated?",
                "id": "6",
            }
        ]
    }
]

# %%
# Answer questions with the model.

answers, probabilities = model.predict(questions)

print(answers)
print(probabilities)
# Out:
# convert squad examples to features: 100%|██████████| 7/7 [00:00<00:00, 293.14it/s]
# add example index and unique id: 100%|██████████| 7/7 [00:00<00:00, 70577.23it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Mistborn of great power and skill', 'Mistborn', 'great power and skill']}, {'id': '1', 'answer': ['2018', 'in 2018', '2018 by researchers at Google.']}, {'id': '2', 'answer': ['empty']}, {'id': '3', 'answer': ['', 'The 2022 FIFA World Cup was a professional association football tournament, the world championship for national football teams organized by FIFA. The 22nd edition of the FIFA World Cup, it took place in Qatar from 20 November to 18 December 2022, after the country was awarded the hosting rights in 2010']}, {'id': '4', 'answer': ['Lionel Messi', 'Argentine captain Lionel Messi']}, {'id': '5', 'answer': ['the third planet from the Sun', 'third planet from the Sun', 'the third planet']}, {'id': '6', 'answer': ['Earth', 'Earth is the third planet from the Sun']}]
# [{'id': '0', 'probability': [0.49506889063626297, 0.29446662702947174, 0.17825454393439885]}, {'id': '1', 'probability': [0.9704974607651009, 0.028571741250100965, 0.0008555551774860292]}, {'id': '2', 'probability': [3.9432352138231733e-07]}, {'id': '3', 'probability': [0.9999999212912953, 3.9969214018241405e-08]}, {'id': '4', 'probability': [0.9475845444860057, 0.04015646101985296]}, {'id': '5', 'probability': [0.659904675355025, 0.24276536319602865, 0.09732276153249277]}, {'id': '6', 'probability': [0.909009215640787, 0.06332579387611799]}]
